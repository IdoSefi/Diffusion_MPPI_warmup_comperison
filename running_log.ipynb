# %% [markdown]
# # first bringup run on mlp with large maze didnt learn very good.
# now we will try to do it on u maze:
#
# train with: python train_diffusion.py --epochs 20 --batch_size 256 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --use_wandb --visualize_trajectories 4 --wandb_group mlp_bringup
#
# checkpoint at /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/u_maze/try1_20epoch/final_step_50800.pt
#
# running evaluation with: python eval_vanilla_mppi.py --episodes 10 --use_diffusion_policy --diff_arch mlp --diff_ckpt /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/u_maze/try1_20epoch/final_step_50800.pt --diff_num_inference_steps 50 --save_video --save_grid_video --logs_dir "Umase_diffusion_only_mlp_bringup_test"

# %% [markdown]
# now we will try to do it on medium maze:
#
# train with: python train_diffusion.py --epochs 200 --batch_size 256 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --use_wandb --visualize_trajectories 9 --wandb_group mlp_bringup_medium --wandb_run_name "medium_actio_only"
#
# checkpoint at /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/medium_maze/trajectory_only/final_step_676200.pt
#
# running evaluation with: python eval_vanilla_mppi.py --episodes 10 --use_diffusion_policy --diff_arch mlp --diff_ckpt /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/medium_maze/trajectory_only/final_step_676200.pt --diff_num_inference_steps 50 --save_video --save_grid_video --logs_dir "medium_mase_diffusion_only_mlp_bringup_test"

# %% [markdown]
# now we will try to get the diffusion of (state,action) trajectories.
# ## currently not normalized
#
# train with: python train_diffusion.py --epochs 20 --batch_size 256 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --use_wandb --visualize_trajectories 9 --wandb_group mlp_bringup_medium --wandb_run_name "medium_state_actions"
#
# checkpoint at /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/medium_maze/state_action_first_100epoch/final_step_338100.pt
#
# running evaluation with: python eval_vanilla_mppi.py --episodes 10 --use_diffusion_policy --diff_arch mlp --diff_ckpt /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/medium_maze/state_action_first_100epoch/final_step_338100.pt --diff_num_inference_steps 50 --save_video --save_grid_video --logs_dir "medium_mase_diffusion_only_mlp_bringup_test_stateAction_restored_late_sat"

# %% [markdown]
# now running with MPPI warmstart
# running evaluation with: python eval_vanilla_mppi.py --episodes 10 --diff_arch mlp --diff_ckpt /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/medium_maze/state_action_first_100epoch/final_step_338100.pt --diff_num_inference_steps 50 --save_video --save_grid_video --logs_dir "medium_mase_MPPI_warmstart_naction10" --plan_method "mppi_warmstart_by_diffusion" --apply_first_n_actions 10 --warmstart_time_limit 0.05
#
# achieving good results with: (one MPPI refinment step)
# python eval_vanilla_mppi.py --episodes 10 --diff_arch mlp --diff_ckpt /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/medium_maze/state_action_first_100epoch/final_step_338100.pt --diff_num_inference_steps 50 --save_video --save_grid_video --logs_dir "medium_mase_MPPI_warmstart_naction5_guidance" --plan_method "mppi_warmstart_by_diffusion" --apply_first_n_actions 5 --warmstart_time_limit 0.11
#
# trying MPPI alone:
# python eval_vanilla_mppi.py --episodes 10 --save_video --save_grid_video --logs_dir "medium_mase_MPPI_only" --plan_method "mppi_only"

# %% [markdown]
# training all three architectures:
#
# #mlp short:
# python train_diffusion.py --epochs 2 --batch_size 256 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --use_wandb --visualize_trajectories 9 --wandb_group mlp --wandb_run_name "small" --wandb_project "final_train"
#
# #cnn short:
# python train_diffusion.py --model_module diffusion_cnn_arch --model_class TrajectoryCNNDenoiser --hidden_dim 256 --depth 8 --time_emb_dim 128 --dropout 0.0 --epochs 2 --batch_size 256 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --use_wandb --visualize_trajectories 9 --wandb_group "cnn" --wandb_run_name "small" --wandb_project "final_train"
#
# #mlp short:
# python train_diffusion.py --model_module diffusion_transformer_arch --model_class TrajectoryTransformerDenoiser --hidden_dim 256 --depth 6 --time_emb_dim 128 --dropout 0.1 --epochs 2 --batch_size 256 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --use_wandb --visualize_trajectories 9 --wandb_group "transformer" --wandb_run_name "small" --wandb_project "final_train"

# %%
I trained long in all 3 arch, used BS256 and BS32:
#!/bin/bash

# Train MLP architecture
python train_diffusion.py --epochs 400 --batch_size 256 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --use_wandb --visualize_trajectories 9 --wandb_group mlp --wandb_run_name "big" --wandb_project "final_train"

# Train CNN architecture
python train_diffusion.py --model_module diffusion_cnn_arch --model_class TrajectoryCNNDenoiser --hidden_dim 256 --depth 8 --time_emb_dim 128 --dropout 0.0 --epochs 400 --batch_size 256 --use_wandb --visualize_trajectories 9 --wandb_group "cnn" --wandb_run_name "big" --wandb_project "final_train"

# Train Transformer architecture
python train_diffusion.py --model_module diffusion_transformer_arch --model_class TrajectoryTransformerDenoiser --hidden_dim 256 --depth 6 --time_emb_dim 128 --dropout 0.1 --epochs 400 --batch_size 256 --use_wandb --visualize_trajectories 9 --wandb_group "transformer" --wandb_run_name "big" --wandb_project "final_train"

# %% [markdown]
# testing cnn arch long train:
# checkpoint at: /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/final_test_medium_maze/cnn_32BS/val_best_24.pt
#
# running evaluation with: python eval_vanilla_mppi.py --episodes 10 --use_diffusion_policy --diff_arch cnn --diff_ckpt /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/final_test_medium_maze/cnn_32BS/val_best_24.pt --diff_num_inference_steps 50 --save_video --save_grid_video --logs_dir "ALL_3_TEST_CNN_BS32_try1"
#
# very very bad!!!

# %% [markdown]
# lets try the transformer:
# python eval_vanilla_mppi.py --episodes 10 --use_diffusion_policy --diff_arch transformer --diff_ckpt /home/user_229/Diffusion_MPPI_comp/results_transformer_big_BS32/val_best_4.pt --diff_num_inference_steps 100 --save_video --save_grid_video --logs_dir "ALL_3_TEST_transformer_BS32_try1"

# %% [markdown]
# adding normalization. testing the CNN on it
# python train_diffusion.py --model_module diffusion_cnn_arch --model_class TrajectoryCNNDenoiser --hidden_dim 256 --depth 8 --time_emb_dim 128 --dropout 0.0 --epochs 1000 --batch_size 32 --use_wandb --wandb_group "cnn" --wandb_run_name "CNN_big_BS32" --wandb_project "final_train_norm" --out_dir "results_norm_cnn_big_BS32"
#
# checkpoint: /home/user_229/Diffusion_MPPI_comp/results_norm_cnn_big_BS32/val_best_1.pt
#
# evaluation:
# python eval_vanilla_mppi.py --episodes 10 --use_diffusion_policy --diff_arch cnn --diff_ckpt /home/user_229/Diffusion_MPPI_comp/results_norm_cnn_big_BS32/val_best_1.pt --diff_num_inference_steps 50 --save_video --save_grid_video --logs_dir "A_NORM_TEST_CNN_BS32_try1"

# %% [markdown]
# ## FINAL EVALUATION

# %% [markdown]
# * see how much time the transformet thinks:
#
# python eval_vanilla_mppi.py --episodes 2 --use_diffusion_policy --diff_arch transformer --diff_ckpt /home/user_229/Diffusion_MPPI_comp/results_transformer_big_BS32/val_best_4.pt --diff_num_inference_steps 100 --save_video --logs_dir "ALL_3_TEST_transformer_BS32_try1"
#
# #for 30 denoising : 0.17 sec (first 0.3)
# #for 100 denoising : 0.37 sec (first 0.5)
#
# ## CNN:
# python eval_vanilla_mppi.py --episodes 10 --use_diffusion_policy --diff_arch cnn --diff_ckpt /home/user_229/Diffusion_MPPI_comp/checkpoints_dir/medium_maze/medium_s_a_after_chat_fix/final_step_67620.pt --diff_num_inference_steps 100 --save_video --save_grid_video --logs_dir "A_NORM_TEST_CNN_BS32_try1" --plan_method mppi_warmstart_by_diffusion
#
# #for 30 denoising : 0.19 sec (first 0.32)
# #for 100 denoising : 0.4 sec (first 0.6)
#
# ## mlp
# # Train MLP architecture
# train_diffusion.py --epochs 300 --batch_size 32 --model_module diffusion_mlp_arch --model_class TrajectoryMLPDenoiser --wandb_group mlp --wandb_run_name mlp_big_final --wandb_project final_train2 --out_dir results_mlp_big_final_noder --use_wandb
# * test
# python eval_vanilla_mppi.py --episodes 2 --use_diffusion_policy --diff_arch mlp --diff_ckpt /home/user_229/Diffusion_MPPI_comp/results_mlp_big_final_noder/val_best_4.pt --diff_num_inference_steps 100 --save_video --logs_dir "FINAL_TEST_MORNING_mlp_100denoise_n_actions5" --plan_method "mppi_warmstart_by_diffusion" --apply_first_n_actions 5
#
#
# # train better CNN with positional embedding
# python train_diffusion.py --model_module diffusion_cnn_arch --model_class TrajectoryCNNDenoiser --hidden_dim 256 --depth 6 --time_emb_dim 128 --dropout 0.0 --epochs 1000 --batch_size 32 --use_wandb --wandb_group "cnn" --wandb_run_name "CNN_big_BS32" --wandb_project "final_train_norm" --out_dir "results_norm_cnn_big_BS32"
#
# python train_diffusion.py --epochs 300 --batch_size 32 --model_module diffusion_cnn_arch --model_class TrajectoryCNNDenoiser --wandb_group mlp --wandb_run_name mlp_big_final --wandb_project final_train2 --out_dir results_mlp_big_final_noder --use_wandb
#
# python train_diffusion.py \
#   --model_module diffusion_cnn_arch \
#   --model_class TrajectoryCNNDenoiser \
#   --hidden_dim 256 \
#   --depth 6 \
#   --kernel_size 5 \
#   --time_emb_dim 128 \
#   --dropout 0.0 \
#   --epochs 300 \
#   --batch_size 32 \
#   --use_wandb \
#   --wandb_group "cnn_fixed" \
#   --wandb_run_name "CNN_Fast_PosEmb" \
#   --wandb_project "final_train2" \
#   --out_dir "results_cnn_fast"
#
#
#   * eval first cnn
#   /home/user_229/Diffusion_MPPI_comp/results_cnn_fast/val_best_1.pt
#   python eval_vanilla_mppi.py --episodes 2 --use_diffusion_policy --diff_arch cnn --diff_ckpt /home/user_229/Diffusion_MPPI_comp/results_cnn_fast/val_best_1.pt --diff_num_inference_steps 30 --save_video --logs_dir "FINAL_TEST_MORNING_cnn_fixed_30denoise_n_actions5" --plan_method "mppi_warmstart_by_diffusion" --apply_first_n_actions 5
#
#   * train transformer:
#   python train_diffusion.py   --model_module diffusion_transformer_arch   --model_class TrajectoryTransformerDenoiser   --hidden_dim 512   --depth 6   --dropout 0.0   --epochs 300   --batch_size 128   --use_wandb   --wandb_group "transformer_fixed"   --wandb_run_name "Trans_Prefix_Large_512"   --wandb_project "final_train2"   --out_dir "results_trans_large"
#
#   * training a turbo cnn:
#
#   checkpoints at: /home/user_229/Diffusion_MPPI_comp/results_cnn_turbo/val_best_22.pt
#
#   evaluating
#   python eval_vanilla_mppi.py --episodes 4 --use_diffusion_policy --diff_arch cnn --diff_ckpt /home/user_229/Diffusion_MPPI_comp/results_cnn_turbo/val_best_22.pt --diff_num_inference_steps 100 --save_video --logs_dir "FINAL_TEST_MORNING_cnn_turbo_diffusionOnly_30denoise_n_actions5" --plan_method "mppi_warmstart_by_diffusion" --apply_first_n_actions 5 --warmstart_time_limit 0.01
